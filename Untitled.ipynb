# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pathlib
# Out:
# 2022-02-16 14:26:48.847957: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-16 14:26:48.847984: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import PIL
import PIL.Image

# %%
dataset_url= "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file(origin=dataset_url,
                                   fname='flower_photos'
                                  untar=True)
data_dir= pathlib.Path(data_dir)

# %%
data_dir= pathlib.Path('flowers')
image_count = len(list(data_dir.glob('*/*.jpg')))
image_count
# Out:
# 4317

# %%
roses = list(data_dir.glob('rose/*.jpg'))
print(len(roses))

PIL.Image.open(str(roses[1]))
# Out:
# 784
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x7F25DCCF3790>

# %%
batch_size=32
image_height=180
image_width= 180

# %%
train_data= tf.keras.utils.image_dataset_from_directory(data_dir,
                                                       seed=121,
                                                       validation_split=0.2,
                                                        subset='training',
                                                       batch_size= batch_size,
                                                       image_size=(image_height, image_width))
# Out:
# Found 4317 files belonging to 5 classes.
# Using 3454 files for training.

# %%
val_Ds = tf.keras.utils.image_dataset_from_directory(data_dir,
                                                    seed=121,
                                                    validation_split=0.2,
                                                    subset='validation',
                                                    batch_size= batch_size,
                                                    image_size= (image_height,image_width))
# Out:
# Found 4317 files belonging to 5 classes.
# Using 863 files for validation.

# %%
print(train_data.class_names)
# Out:
# ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']

# %%
class_names= train_data.class_names
plt.figure(figsize=(10,10))
for images, labels in train_data.take(1):
    for i in range(9):
        ax= plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis('off')

# %%
for train_batch, labels_batch in train_data:
    print(train_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
from tensorflow import keras
from tensorflow.keras import layers
inputs= keras.Input(shape=(180,180,3))
x= layers.Rescaling(1./255)(inputs)

x= layers.Conv2D(filters=32,kernel_size=3, activation='relu')(x)
x= layers.MaxPooling2D(pool_size=2)(x)
x= layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x= layers.Flatten()(x)
outputs=layers.Dense(len(class_names), activation='softmax')(x)
model =  keras.Model(inputs= inputs, outputs= outputs)
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling_7 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d_1 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  flatten_2 (Flatten)         (None, 484416)            0
#
#  dense_12 (Dense)            (None, 5)                 2422085
#
# =================================================================
# Total params: 2,441,477
# Trainable params: 2,441,477
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, 'train.png')
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
callbacks= [keras.callbacks.ModelCheckpoint("flower_dense.keras",
                                            monitor='val_accuracy',
                                          save_best_only=True),
          ]
""" keras.callbacks.EarlyStopping(monitor='val_loss',
                                        patience=2)"""
# Out:
# " keras.callbacks.EarlyStopping(monitor='val_loss',\n                                        patience=2)"

# %%
model.compile(optimizer='rmsprop',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
history= model.fit(train_data, 
                  epochs=10,
                  validation_data=val_Ds,
                  callbacks=callbacks)
# Out:
# Epoch 1/10
# 108/108 [==============================] - 35s 322ms/step - loss: 2.3044 - accuracy: 0.4438 - val_loss: 1.1855 - val_accuracy: 0.5110
# Epoch 2/10
# 108/108 [==============================] - 36s 332ms/step - loss: 0.9421 - accuracy: 0.6589 - val_loss: 1.4645 - val_accuracy: 0.4948
# Epoch 3/10
# 108/108 [==============================] - 36s 334ms/step - loss: 0.5113 - accuracy: 0.8335 - val_loss: 1.4312 - val_accuracy: 0.5319
# Epoch 4/10
# 108/108 [==============================] - 36s 334ms/step - loss: 0.2509 - accuracy: 0.9343 - val_loss: 1.8128 - val_accuracy: 0.4948
# Epoch 5/10
# 108/108 [==============================] - 36s 337ms/step - loss: 0.1245 - accuracy: 0.9635 - val_loss: 2.2059 - val_accuracy: 0.4948
# Epoch 6/10
# 108/108 [==============================] - 36s 335ms/step - loss: 0.0840 - accuracy: 0.9783 - val_loss: 2.5700 - val_accuracy: 0.5214
# Epoch 7/10
# 108/108 [==============================] - 38s 348ms/step - loss: 0.0961 - accuracy: 0.9806 - val_loss: 2.7062 - val_accuracy: 0.4925
# Epoch 8/10
# 108/108 [==============================] - 37s 339ms/step - loss: 0.1066 - accuracy: 0.9864 - val_loss: 2.8464 - val_accuracy: 0.5029
# Epoch 9/10
# 108/108 [==============================] - 37s 340ms/step - loss: 0.0578 - accuracy: 0.9858 - val_loss: 3.2600 - val_accuracy: 0.4902
# Epoch 10/10
# 108/108 [==============================] - 37s 342ms/step - loss: 0.0590 - accuracy: 0.9896 - val_loss: 3.3522 - val_accuracy: 0.5156

# %%
data_augmentation= keras.Sequential([
                                    layers.RandomFlip('horizontal'),
                                    layers.RandomZoom(0.2),
                                    layers.RandomRotation(0.1)
])

# %%
inputs= keras.Input(shape=(180,180,3))
x= data_augmentation(inputs)
x= layers.Rescaling(1./255)(x)
x= layers.Conv2D(filters=32, kernel_size=3, activation='relu')(x)
x= layers.MaxPooling2D(pool_size=2)(x)
x= layers.Conv2D(filters=64, kernel_size=3, activation='relu')(x)
x= layers.MaxPooling2D(pool_size=2)(x)
x= layers.Conv2D(filters=128, kernel_size=3, activation='relu')(x)
x= layers.MaxPooling2D(pool_size=2)(x)
x= layers.Flatten()(x)
outputs= layers.Dense(5, activation='softmax')(x)
model= keras.Model(inputs= inputs, outputs= outputs)
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 180, 180, 3)]     0
#
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  rescaling_11 (Rescaling)    (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_6 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_8 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  flatten_4 (Flatten)         (None, 51200)             0
#
#  dense_14 (Dense)            (None, 5)                 256005
#
# =================================================================
# Total params: 349,253
# Trainable params: 349,253
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop',
             loss="sparse_categorical_crossentropy",
             metrics=['accuracy'])

# %%
history= model.fit(train_data,
                   epochs=20,
                   validation_data= val_Ds,
                   callbacks= callbacks
                  )
# Out:
# Epoch 1/20
# 108/108 [==============================] - 50s 463ms/step - loss: 0.7592 - accuracy: 0.7232 - val_loss: 0.8110 - val_accuracy: 0.6871
# Epoch 2/20
# 108/108 [==============================] - 53s 487ms/step - loss: 0.7306 - accuracy: 0.7273 - val_loss: 0.7825 - val_accuracy: 0.7138
